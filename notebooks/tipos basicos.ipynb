# %%
Tipos de Dados:
"Olá Mundo" → string
True → booleano
-25 → inteiro
1.167 → float
' ' → string

# %%
Resultados dos Prints:
50
15
"Ola Mundo"
"Ola Ola "
" "
"la "

# %%
Concatenar e Exibir Strings:
Quarta variável completa: "Python-É-Legal"
5 primeiros caracteres: "Python"
5 últimos caracteres: "Legal"
