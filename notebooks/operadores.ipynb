# %%
#exercício 1

# %%
variavel1 = 6

# %%
variavel3 = 4

# %%
variavel2 = 8

# %%
media = (variavel1 + variavel2 + variavel3 )/ 3

# %%
print("a nota média é {}".format(media))
# Out:
# a nota média é 6.0

# %%
#exercício 2

# %%
variavel1 = 6

# %%
variavel2 = 8

# %%
variavel3 = 4

# %%
variavel4 = 10

# %%
peso1 = 0.15

# %%
peso2 = 0.35

# %%
peso3 = 0.20

# %%
peso4 = 0.30

# %%
media2 = (variavel1 * peso1) + (variavel2 * peso2) + (variavel3 * peso3) + (variavel4 * peso4)

# %%
print("a média ponderada é {}".format(media2))
# Out:
# a média ponderada é 7.5

# %%
#exercício 3

# %%
valor1 = float(input("digite o primeiro numero"))
# Out:
# digite o primeiro numero 4

# %%
valor2 = float(input("digite o segundo numero"))
# Out:
# digite o segundo numero 5

# %%
iguais = valor1 == valor2

# %%
diferentes = valor1 != valor2

# %%
maior = valor1 > valor2

# %%
maior_igual = valor1 >= valor2

# %%
print("os dois numeros são iguais? {}".format(iguais))
# Out:
# os dois numeros são iguais? False

# %%
print("os dois numeros são diferentes? {}".format(diferentes))
# Out:
# os dois numeros são diferentes? True

# %%
print("o primeiro número é maior que o segundo? {}".format(maior))
# Out:
# o primeiro número é maior que o segundo? False

# %%
print("o primeiro número é igual ou maior que o segundo número? {}".format(maior_igual))
# Out:
# o primeiro número é igual ou maior que o segundo número? False

# %%
# exercício 4

# %%
valor_a = str(input("digite um valor"))
# Out:
# digite um valor 232244

# %%
valor_b = str(input("digite outro valor"))
# Out:
# digite outro valor 2423543223

# %%
comprimento1 = 3<= len(valor_a) <10

# %%
comprimento2 = 3<= len(valor_b) <10

# %%
print("o primeiro valor é valido? {}".format(comprimento1))
# Out:
# o primeiro valor é valido? True

# %%
print("o segundo valor é valido? {}".format(comprimento2))
# Out:
# o segundo valor é valido? False

# %%
# exercício 5

# %%
numero_magico = 12345679

# %%
usuario = int(input("digite um valor de 1 a 9 somente"))
# Out:
# digite um valor de 1 a 9 somente 6

# %%
numero_ultilizador = usuario * 9

# %%
numero_magico *= numero_ultilizador

# %%
print("o número mágico é {}".format(numero_magico))
# Out:
# o número mágico é 666666666
